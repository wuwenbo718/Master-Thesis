# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
import data_processing as dp
from scipy import signal
from scipy.stats import skew
import seaborn as sns
import matplotlib.pyplot as plt
import pywt
import os
import time
import h5py
from itertools import combinations

# %%
# read file name of data with various Labels
df = pd.read_csv('./useful_data_label.csv',index_col=0) 
# read file name of data with only label 0
df2 = pd.read_csv('./unuseful_data_label.csv',index_col=0)
# read some of the data with only label 0
df3 = pd.read_csv('./data/file_name.txt',header=None)

# %%
import imp
imp.reload(dp)
# Out:
# <module 'data_processing' from 'E:\\Document\\jupyter\\Master Thesis\\data_processing.py'>

# %%
# read the data and labels of df2 or df3
sc = StandardScaler(with_mean = False)
#sc = MinMaxScaler()
ind = df2.iloc[1].isna()
#files = np.concatenate([np.array(df.columns),np.array('正常/'+df2.columns[ind])])
files = np.array(df.columns[[2,5,6,7,8,10,11,12,13,16,17,18,19,20]])
N = len(files)
#sc = StandardScaler(with_mean=False)
width = 256
stride = 64
start = time.time()
i = 0
X = []
Y = []
X2 = []
Y2 = []
F = []
F2 = []
for file in files:
    i += 1
    if file.find('G04')==0:
        continue
    emg_data = pd.read_csv('./data/'+file)
    #emg_data.iloc[:,3:] = 
    emg_data = emg_data.dropna().reset_index(drop=True)
    #emg_data.iloc[:,3:]=normalize(emg_data.iloc[:,3:],axis=0)
    #emg_data.iloc[:,3:] = sc.fit_transform(emg_data.iloc[:,3:])
    fn = 300
    wn=2*fn/1000
    fn1 = 300
    wn1 = 2*fn1/1000
    fs = 1000.0  # Sample frequency (Hz)
    f0 = 50  # Frequency to be removed from signal (Hz)
    Q = 100.0  # Quality factor
    # Design notch filter
    #b1, a1 = signal.iirnotch(f0, Q, fs)
    #b, a = signal.butter(4, [wn,wn1], 'bandpass')
    b, a = signal.butter(4, [wn], 'lowpass')
    #for j in ['LEFT_TA','LEFT_TS','LEFT_BF','LEFT_RF','RIGHT_TA','RIGHT_TS','RIGHT_BF','RIGHT_RF']:
        #emg_data.loc[:,j] = signal.filtfilt(b, a, emg_data.loc[:,j])
        #emg_data.loc[:,j] = signal.filtfilt(b1, a1, emg_data.loc[:,j])
    x,y = dp.generate_window_slide_data(emg_data,width=width,
                                        stride=stride,
                                        scaler=False,
                                        same_label=True)
    #x=np.abs(x)
    #x=dp.lowpass_filter(x,300)
    ind1 = []
    ind2 = []
    l = len(y)
    for j in set(y):
        ind = np.where(y == j)[0].tolist()
        l_t = len(ind)
        ind1 += ind[:int(l_t*0.8)]
        ind2 += ind[int(l_t*0.8):]

    l1 = len(ind1)
    l2 = len(ind2)

    fi = [file]*len(ind1)
    fi2 = [file]*len(ind2)
    X += x[ind1].tolist()
    Y += y[ind1].tolist()
    F += fi
    X2 += x[ind2].tolist()
    Y2 += y[ind2].tolist()
    F2 += fi2
    print('%d/%d: '%(i,N)+file)

ind_c = [True,True,False,False,True,True,False,False]
X = np.array(X)#[:,:,ind_c]
Y = np.array(Y)
X2 = np.array(X2)#[:,:,ind_c]
Y2 = np.array(Y2)
end = time.time()
duration = end-start
print('Duration: %f'%(duration))
# Out:
# 1/14: G06_FoG_trial_1_emg.csv
# 2/14: G07_Freezing_Trial1_trial_1_emg.csv
# 3/14: G08_FoG_1_trial_1_emg.csv
# 4/14: G08_FoG_2_trial_1_emg.csv
# 5/14: G11_FoG_trial_1_emg.csv
# 6/14: P379_M050_2_OFF_A_FoG_trial_1_emg.csv
# 7/14: P379_M050_2_OFF_A_FoG_trial_2_emg.csv
# 8/14: P379_M050_2_OFF_A_FoG_trial_3_emg.csv
# 9/14: P379_M050_2_OFF_B_FoG_trial_1_emg.csv
# 10/14: P551_M050_2_A_FoG_trial_1_emg.csv
# 11/14: P551_M050_2_B_FoG_trial_1_emg.csv
# 12/14: P551_M050_2_B_FoG_trial_2_emg.csv
# 13/14: P812_M050_2_B_FoG_trial_1_emg.csv
# 14/14: P812_M050_2_B_FoG_trial_2_emg.csv
# Duration: 38.812809

# %%
def get_features_from_dwt(data,wavelet='db7',level=5):
    coes = pywt.wavedec(data,wavelet=wavelet,mode=0,level=level,axis=1)
    n,l,c = coes[-1].shape
    feature = np.zeros((n,l,c,0))
    for i in range(len(coes)-1):
        temp = signal.resample(coes[i],l,axis=1)[:,:,:,np.newaxis]
        feature = np.concatenate([feature,temp],axis=3)
        #print(feature.shape)
    #print(coes[-1].shape)
    feature = np.concatenate([feature,coes[-1][:,:,:,np.newaxis]],axis=3)
    return feature

# %%
wavelet = 'haar'
level = 3
feature=get_features_from_dwt(X,wavelet,level).transpose((0,2,1,3))
feature2=get_features_from_dwt(X2,wavelet,level).transpose((0,2,1,3))

# %%
plt.plot(feature[0,0,:,3])
#plt.figure()
#plt.plot(feature.transpose((0,2,1,3))[10,0,:,4])

# %%
feature.shape
# Out:
# (2199, 6, 512, 8)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import save_model,load_model
from tensorflow.keras import callbacks, Model, models
from tensorflow.keras.losses import BinaryCrossentropy,CategoricalCrossentropy
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import TruncatedNormal
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve,confusion_matrix,accuracy_score
import tensorflow as tf
from tensorflow.keras import backend as K
from imblearn.over_sampling import SMOTE

# %%
def train_model(model,feature,y,binary=True,file=None):
    if binary:
        ind = ((y==0)|(y==1)|(y==2)|(y==3)|(y==4)|(y==6))
        ind1 = ((y==4)|(y==1)|(y==2)|(y==3)|(y==6))
        y_01 = y.copy()
        #ind1 = ((y_01==1)|(y_01==2)|(y_01==6))
        y_01[ind1] = 1
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:1,1:5}
    else:
        ind = ((y==1)|(y==2)|(y==6))
        #ind = ((y==2)|(y==6))
        y_01 = y[ind].copy()
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:5,1:1,2:1}#{0:2,1:1,2:10,3:2}
    x_full,x_test,y_full,y_test = train_test_split(np.array(feature)[ind,:],y_01,
                                                   test_size=0.2,
                                                   random_state=123,
                                                   shuffle=True)
    x_train,x_valid,y_train,y_valid = train_test_split(x_full,y_full,
                                                       test_size=0.25,
                                                       random_state=555,
                                                       shuffle=True)
    
    x_train = x_full
    
    early_stopping = callbacks.EarlyStopping(patience = 10,
                                             monitor = 'val_loss', 
                                             restore_best_weights=True)
    history = model.fit(x_train,y_full,validation_data=(x_test,y_test),
                        epochs=300,batch_size=32,class_weight=cw,
                        callbacks=[early_stopping],
                        shuffle=True)
    
    if binary:
        y_pred_t=model.predict(x_test)
        test = accuracy_score(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1))
        #test = accuracy_score(y_test,y_pred_t>0.5)
        
        #y_pred_v=model.predict(x_valid)
        #valid = accuracy_score(y_valid,np.argmax(y_pred_v,axis=1))
        y_pred_ta=model.predict(x_train)
        train = accuracy_score(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1))
        #train = accuracy_score(y_full,y_pred_ta>0.5)
        
        print('train: \n',confusion_matrix(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1)))
        #print('valid: \n',confusion_matrix(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1)))
        print('test: \n',confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1)))
        
        #print('train: \n',metrics.confusion_matrix(y_full,y_pred_ta>0.5))
        #print('test: \n',metrics.confusion_matrix(y_test,y_pred_t>0.5))

    else:
        y_pred_t=model.predict(x_test)
        test = accuracy_score(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1))
        #y_pred_v=model.predict(x_valid)
        #valid = metrics.accuracy_score(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1))
        y_pred_ta=model.predict(x_train)
        train = accuracy_score(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1))        
        print('train: \n',confusion_matrix(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1)))
        #print('valid: \n',confusion_matrix(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1)))
        print('test: \n',confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1)))
    print('test:%f'%test)
    #print('valid:%f'%valid)
    print('train:%f'%train)
    if file != None:
        model.save_model(file)
    return train,test

def test_model(model,feature,y,binary=True):
    if binary:
        ind = ((y==0)|(y==1)|(y==2)|(y==3)|(y==4)|(y==6))
        #ind1 = ((y==4)|(y==1)|(y==2)|(y==3)|(y==6))
        y_01 = y[ind].copy()
        ind1 = ((y_01==1)|(y_01==2)|(y_01==6))
        y_01[ind1] = 1
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:1,1:5}
    else:
        ind = ((y==1)|(y==2)|(y==6))
        #ind = ((y==2)|(y==6))
        y_01 = y[ind].copy()
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:5,1:1,2:1}#{0:2,1:1,2:10,3:2}

    #print(y_01)
    #feature=sc.transform(feature[ind])
    #feature=pca.transform(feature)
    y_pred=model.predict(feature[ind])
    test = accuracy_score(np.argmax(y_01,axis=1),np.argmax(y_pred,axis=1))
    #test = metrics.accuracy_score(y_01,y_pred>0.5)
    
    print('acc:%f'%test)
    print(confusion_matrix(np.argmax(y_01,axis=1),np.argmax(y_pred,axis=1)))
    #print(metrics.confusion_matrix(y_01,y_pred>0.5))
    return test

def sparse_cost_sensitive_loss (y_true,y_pred):
    #cost_matrix = tf.constant([[0,1.5,1,1.5],
    #              [1,0,1,1],
    #              [5,10,0,5],
    #              [1.,1.,1,0]])
    cost_matrix = tf.constant([[0,2.,2],
                  [1,0,1],
                  [1.0,2.,0]])
    batch_cost_matrix = tf.nn.embedding_lookup(cost_matrix, tf.argmax(y_true,axis=1))
    eps = 1e-6
    probability = tf.clip_by_value(y_pred, eps, 1-eps)
    cost_values = tf.math.log(1-probability)*batch_cost_matrix
    loss = tf.reduce_mean(-tf.reduce_sum(cost_values, axis=1))
    return loss

# %%
rate=0.2
kernel_size=7
stride=2
acti='relu'

# %%
input_ = layers.Input(shape=feature[:,[0,1,4,5],:,:].shape[1:])
#bn = layers.BatchNormalization()(input_)
#max_pool = layers.MaxPooling2D((2,2))(input_)
#bn = layers.BatchNormalization()(input_)

cnn1 = layers.Conv1D(256,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(input_)
#cnn1 = layers.Conv1D(16,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn1)
#cnn1 = layers.BatchNormalization()(cnn1)
cnn1 = layers.Activation(acti)(cnn1)
cnn1 = layers.Dropout(rate)(cnn1)
#cnn1 = layers.MaxPooling1D(2)(cnn1)

cnn2 = layers.Conv1D(128,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(cnn1)
#cnn2 = layers.Conv1D(32,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn2)
cnn2 = layers.BatchNormalization(momentum=0.8)(cnn2)
cnn2 = layers.Activation(acti)(cnn2)
cnn2 = layers.Dropout(rate)(cnn2)
#cnn2 = layers.MaxPooling1D(2)(cnn2)

cnn3 = layers.Conv1D(64,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(cnn2)
#cnn3 = layers.Conv1D(64,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn3)
cnn3 = layers.BatchNormalization(momentum=0.8)(cnn3)
cnn3 = layers.Activation(acti)(cnn3)
cnn3 = layers.Dropout(rate)(cnn3)
#cnn3 = layers.MaxPooling1D(2)(cnn3)

cnn4 = layers.Conv1D(32,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(cnn3)
#cnn4 = layers.Conv1D(32,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn4)
cnn4 = layers.BatchNormalization(momentum=0.8)(cnn4)
cnn4 = layers.Activation(acti)(cnn4)
cnn4 = layers.Dropout(rate)(cnn4)
#cnn4 = layers.MaxPooling1D(2)(cnn4)

cnn5 = layers.Conv1D(16,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(cnn4)
#cnn5 = layers.Conv1D(16,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn4)
cnn5 = layers.BatchNormalization(momentum=0.8)(cnn5)
cnn5 = layers.Activation(acti)(cnn5)
cnn5 = layers.Dropout(rate)(cnn5)
#cnn4 = layers.MaxPooling1D(2)(cnn4)

cnn6 = layers.Conv1D(8,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
                      padding='same')(cnn5)
#cnn5 = layers.Conv1D(16,kernel_size,strides=stride,
                      #kernel_initializer=TruncatedNormal(),
                      #use_bias=False,#activation='elu',
#                      padding='same')(cnn4)
cnn6 = layers.BatchNormalization(momentum=0.8)(cnn6)
cnn6 = layers.Activation(acti)(cnn6)
cnn6 = layers.Dropout(rate)(cnn6)
#cnn4 = layers.MaxPooling1D(2)(cnn4)

flatten = layers.Flatten()(cnn6)
dropout = layers.Dropout(rate)(flatten)
#layer1 = layers.Dense(256,activation = 'relu')(dropout)
#dropout1 = layers.Dropout(0.2)(layer1)
#layer2 = layers.Dense(128,activation = 'relu')(dropout1)
#dropout2 = layers.Dropout(0.2)(layer2)
output = layers.Dense(3,activation = 'softmax')(dropout)
model = Model(inputs=[input_],outputs=[output])

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#early_stopping = callbacks.EarlyStopping(patience = 10,monitor = 'val_accuracy', restore_best_weights=True)

# %%
model.summary()
# Out:
# Model: "functional_153"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_80 (InputLayer)        [(None, 4, 128, 4)]       0
# _________________________________________________________________
# conv1d_392 (Conv1D)          (None, 4, 64, 256)        7424
# _________________________________________________________________
# activation_383 (Activation)  (None, 4, 64, 256)        0
# _________________________________________________________________
# dropout_460 (Dropout)        (None, 4, 64, 256)        0
# _________________________________________________________________
# conv1d_393 (Conv1D)          (None, 4, 32, 128)        229504
# _________________________________________________________________
# batch_normalization_300 (Bat (None, 4, 32, 128)        512
# _________________________________________________________________
# activation_384 (Activation)  (None, 4, 32, 128)        0
# _________________________________________________________________
# dropout_461 (Dropout)        (None, 4, 32, 128)        0
# _________________________________________________________________
# conv1d_394 (Conv1D)          (None, 4, 16, 64)         57408
# _________________________________________________________________
# batch_normalization_301 (Bat (None, 4, 16, 64)         256
# _________________________________________________________________
# activation_385 (Activation)  (None, 4, 16, 64)         0
# _________________________________________________________________
# dropout_462 (Dropout)        (None, 4, 16, 64)         0
# _________________________________________________________________
# conv1d_395 (Conv1D)          (None, 4, 8, 32)          14368
# _________________________________________________________________
# batch_normalization_302 (Bat (None, 4, 8, 32)          128
# _________________________________________________________________
# activation_386 (Activation)  (None, 4, 8, 32)          0
# _________________________________________________________________
# dropout_463 (Dropout)        (None, 4, 8, 32)          0
# _________________________________________________________________
# conv1d_396 (Conv1D)          (None, 4, 4, 16)          3600
# _________________________________________________________________
# batch_normalization_303 (Bat (None, 4, 4, 16)          64
# _________________________________________________________________
# activation_387 (Activation)  (None, 4, 4, 16)          0
# _________________________________________________________________
# dropout_464 (Dropout)        (None, 4, 4, 16)          0
# _________________________________________________________________
# conv1d_397 (Conv1D)          (None, 4, 2, 8)           904
# _________________________________________________________________
# batch_normalization_304 (Bat (None, 4, 2, 8)           32
# _________________________________________________________________
# activation_388 (Activation)  (None, 4, 2, 8)           0
# _________________________________________________________________
# dropout_465 (Dropout)        (None, 4, 2, 8)           0
# _________________________________________________________________
# flatten_76 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_466 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 314,395
# Trainable params: 313,899
# Non-trainable params: 496
# _________________________________________________________________

# %%
train_model(model,feature[:,[0,1,4,5],:,:],Y,False)
# Out:
# Epoch 1/300
# 204/204 [==============================] - 54s 263ms/step - loss: 0.9255 - accuracy: 0.5510 - val_loss: 0.8008 - val_accuracy: 0.6342
# Epoch 2/300
# 204/204 [==============================] - 54s 266ms/step - loss: 0.8017 - accuracy: 0.6305 - val_loss: 0.7232 - val_accuracy: 0.6869
# Epoch 3/300
# 204/204 [==============================] - 56s 273ms/step - loss: 0.7554 - accuracy: 0.6527 - val_loss: 0.7161 - val_accuracy: 0.6771
# Epoch 4/300
# 204/204 [==============================] - 57s 280ms/step - loss: 0.7231 - accuracy: 0.6765 - val_loss: 0.6724 - val_accuracy: 0.7083
# Epoch 5/300
# 204/204 [==============================] - 55s 267ms/step - loss: 0.6990 - accuracy: 0.6880 - val_loss: 0.6523 - val_accuracy: 0.7047
# Epoch 6/300
# 204/204 [==============================] - 57s 278ms/step - loss: 0.6796 - accuracy: 0.7036 - val_loss: 0.6452 - val_accuracy: 0.7083
# Epoch 7/300
# 204/204 [==============================] - 54s 265ms/step - loss: 0.6615 - accuracy: 0.7091 - val_loss: 0.6428 - val_accuracy: 0.7365
# Epoch 8/300
# 204/204 [==============================] - 54s 267ms/step - loss: 0.6422 - accuracy: 0.7145 - val_loss: 0.6136 - val_accuracy: 0.7390
# Epoch 9/300
# 204/204 [==============================] - 53s 259ms/step - loss: 0.6263 - accuracy: 0.7168 - val_loss: 0.6097 - val_accuracy: 0.7292
# Epoch 10/300
# 204/204 [==============================] - 56s 276ms/step - loss: 0.6120 - accuracy: 0.7251 - val_loss: 0.5954 - val_accuracy: 0.7414
# Epoch 11/300
# 204/204 [==============================] - 54s 267ms/step - loss: 0.5838 - accuracy: 0.7410 - val_loss: 0.5874 - val_accuracy: 0.7384
# Epoch 12/300
# 204/204 [==============================] - 54s 264ms/step - loss: 0.5785 - accuracy: 0.7522 - val_loss: 0.5564 - val_accuracy: 0.7678
# Epoch 13/300
# 204/204 [==============================] - 58s 283ms/step - loss: 0.5564 - accuracy: 0.7606 - val_loss: 0.5222 - val_accuracy: 0.7825
# Epoch 14/300
# 204/204 [==============================] - 57s 277ms/step - loss: 0.5205 - accuracy: 0.7753 - val_loss: 0.5131 - val_accuracy: 0.7874
# Epoch 15/300
# 204/204 [==============================] - 53s 261ms/step - loss: 0.5217 - accuracy: 0.7779 - val_loss: 0.4977 - val_accuracy: 0.7960
# Epoch 16/300
# 204/204 [==============================] - 54s 263ms/step - loss: 0.4825 - accuracy: 0.7946 - val_loss: 0.4636 - val_accuracy: 0.8064
# Epoch 17/300
# 204/204 [==============================] - 56s 276ms/step - loss: 0.4662 - accuracy: 0.8112 - val_loss: 0.4505 - val_accuracy: 0.8199
# Epoch 18/300
# 204/204 [==============================] - 53s 257ms/step - loss: 0.4531 - accuracy: 0.8124 - val_loss: 0.4354 - val_accuracy: 0.8266
# Epoch 19/300
# 204/204 [==============================] - 51s 251ms/step - loss: 0.4274 - accuracy: 0.8213 - val_loss: 0.4167 - val_accuracy: 0.8309
# Epoch 20/300
# 204/204 [==============================] - 52s 253ms/step - loss: 0.4268 - accuracy: 0.8231 - val_loss: 0.3987 - val_accuracy: 0.8487
# Epoch 21/300
# 204/204 [==============================] - 52s 253ms/step - loss: 0.3899 - accuracy: 0.8395 - val_loss: 0.3647 - val_accuracy: 0.8634
# Epoch 22/300
# 204/204 [==============================] - 53s 260ms/step - loss: 0.3786 - accuracy: 0.8506 - val_loss: 0.3567 - val_accuracy: 0.8627
# Epoch 23/300
# 204/204 [==============================] - 58s 282ms/step - loss: 0.3528 - accuracy: 0.8536 - val_loss: 0.3748 - val_accuracy: 0.8425
# Epoch 24/300
# 204/204 [==============================] - 62s 302ms/step - loss: 0.3637 - accuracy: 0.8590 - val_loss: 0.3664 - val_accuracy: 0.8621
# Epoch 25/300
# 204/204 [==============================] - 56s 273ms/step - loss: 0.3379 - accuracy: 0.8610 - val_loss: 0.3382 - val_accuracy: 0.8725
# Epoch 26/300
# 204/204 [==============================] - 55s 268ms/step - loss: 0.3259 - accuracy: 0.8768 - val_loss: 0.3453 - val_accuracy: 0.8664
# Epoch 27/300
# 204/204 [==============================] - 56s 273ms/step - loss: 0.3116 - accuracy: 0.8734 - val_loss: 0.3072 - val_accuracy: 0.8830
# Epoch 28/300
# 204/204 [==============================] - 58s 283ms/step - loss: 0.3043 - accuracy: 0.8811 - val_loss: 0.3632 - val_accuracy: 0.8597
# Epoch 29/300
# 204/204 [==============================] - 59s 291ms/step - loss: 0.2793 - accuracy: 0.8920 - val_loss: 0.2598 - val_accuracy: 0.9026
# Epoch 30/300
# 204/204 [==============================] - 55s 270ms/step - loss: 0.2631 - accuracy: 0.9011 - val_loss: 0.2734 - val_accuracy: 0.9032
# Epoch 31/300
# 204/204 [==============================] - 52s 253ms/step - loss: 0.2547 - accuracy: 0.9061 - val_loss: 0.2603 - val_accuracy: 0.9130
# Epoch 32/300
# 204/204 [==============================] - 51s 252ms/step - loss: 0.2454 - accuracy: 0.9053 - val_loss: 0.2168 - val_accuracy: 0.9283
# Epoch 33/300
# 204/204 [==============================] - 52s 255ms/step - loss: 0.2513 - accuracy: 0.9044 - val_loss: 0.2540 - val_accuracy: 0.9099
# Epoch 34/300
# 204/204 [==============================] - 54s 263ms/step - loss: 0.2307 - accuracy: 0.9134 - val_loss: 0.2240 - val_accuracy: 0.9308
# Epoch 35/300
# 204/204 [==============================] - 51s 251ms/step - loss: 0.2207 - accuracy: 0.9134 - val_loss: 0.2473 - val_accuracy: 0.9124
# Epoch 36/300
# 204/204 [==============================] - 52s 256ms/step - loss: 0.2280 - accuracy: 0.9133 - val_loss: 0.2240 - val_accuracy: 0.9332
# Epoch 37/300
# 204/204 [==============================] - 56s 273ms/step - loss: 0.2062 - accuracy: 0.9214 - val_loss: 0.1999 - val_accuracy: 0.9406
# Epoch 38/300
# 204/204 [==============================] - 51s 250ms/step - loss: 0.1905 - accuracy: 0.9300 - val_loss: 0.1762 - val_accuracy: 0.9485
# Epoch 39/300
# 204/204 [==============================] - 47s 229ms/step - loss: 0.2015 - accuracy: 0.9241 - val_loss: 0.2214 - val_accuracy: 0.9210
# Epoch 40/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1706 - accuracy: 0.9389 - val_loss: 0.2064 - val_accuracy: 0.9314
# Epoch 41/300
# 204/204 [==============================] - 46s 228ms/step - loss: 0.1858 - accuracy: 0.9330 - val_loss: 0.1599 - val_accuracy: 0.9553
# Epoch 42/300
# 204/204 [==============================] - 47s 230ms/step - loss: 0.1829 - accuracy: 0.9349 - val_loss: 0.1827 - val_accuracy: 0.9387
# Epoch 43/300
# 204/204 [==============================] - 48s 236ms/step - loss: 0.1484 - accuracy: 0.9438 - val_loss: 0.1667 - val_accuracy: 0.9516
# Epoch 44/300
# 204/204 [==============================] - 47s 230ms/step - loss: 0.1876 - accuracy: 0.9352 - val_loss: 0.1833 - val_accuracy: 0.9491
# Epoch 45/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1687 - accuracy: 0.9436 - val_loss: 0.1776 - val_accuracy: 0.9467
# Epoch 46/300
# 204/204 [==============================] - 46s 228ms/step - loss: 0.1539 - accuracy: 0.9450 - val_loss: 0.1731 - val_accuracy: 0.9473
# Epoch 47/300
# 204/204 [==============================] - 46s 228ms/step - loss: 0.1482 - accuracy: 0.9457 - val_loss: 0.1934 - val_accuracy: 0.9449
# Epoch 48/300
# 204/204 [==============================] - 47s 229ms/step - loss: 0.1363 - accuracy: 0.9497 - val_loss: 0.1525 - val_accuracy: 0.9540
# Epoch 49/300
# 204/204 [==============================] - 47s 229ms/step - loss: 0.1592 - accuracy: 0.9425 - val_loss: 0.1653 - val_accuracy: 0.9522
# Epoch 50/300
# 204/204 [==============================] - 48s 233ms/step - loss: 0.1599 - accuracy: 0.9433 - val_loss: 0.2171 - val_accuracy: 0.9338
# Epoch 51/300
# 204/204 [==============================] - 47s 230ms/step - loss: 0.1344 - accuracy: 0.9545 - val_loss: 0.1847 - val_accuracy: 0.9436
# Epoch 52/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1281 - accuracy: 0.9562 - val_loss: 0.1591 - val_accuracy: 0.9540
# Epoch 53/300
# 204/204 [==============================] - 47s 228ms/step - loss: 0.1463 - accuracy: 0.9464 - val_loss: 0.1396 - val_accuracy: 0.9571
# Epoch 54/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1357 - accuracy: 0.9505 - val_loss: 0.1445 - val_accuracy: 0.9553
# Epoch 55/300
# 204/204 [==============================] - 47s 232ms/step - loss: 0.1193 - accuracy: 0.9585 - val_loss: 0.1408 - val_accuracy: 0.9620
# Epoch 56/300
# 204/204 [==============================] - 47s 228ms/step - loss: 0.1267 - accuracy: 0.9542 - val_loss: 0.1687 - val_accuracy: 0.9528
# Epoch 57/300
# 204/204 [==============================] - 46s 225ms/step - loss: 0.1113 - accuracy: 0.9620 - val_loss: 0.1277 - val_accuracy: 0.9638
# Epoch 58/300
# 204/204 [==============================] - 46s 226ms/step - loss: 0.1179 - accuracy: 0.9589 - val_loss: 0.1815 - val_accuracy: 0.9461
# Epoch 59/300
# 204/204 [==============================] - 46s 225ms/step - loss: 0.1084 - accuracy: 0.9597 - val_loss: 0.1363 - val_accuracy: 0.9608
# Epoch 60/300
# 204/204 [==============================] - 46s 226ms/step - loss: 0.1207 - accuracy: 0.9575 - val_loss: 0.1397 - val_accuracy: 0.9632
# Epoch 61/300
# 204/204 [==============================] - 47s 228ms/step - loss: 0.1105 - accuracy: 0.9594 - val_loss: 0.1444 - val_accuracy: 0.9626
# Epoch 62/300
# 204/204 [==============================] - 47s 231ms/step - loss: 0.1099 - accuracy: 0.9580 - val_loss: 0.1338 - val_accuracy: 0.9681
# Epoch 63/300
# 204/204 [==============================] - 47s 233ms/step - loss: 0.1130 - accuracy: 0.9602 - val_loss: 0.1342 - val_accuracy: 0.9638
# Epoch 64/300
# 204/204 [==============================] - 46s 228ms/step - loss: 0.0970 - accuracy: 0.9643 - val_loss: 0.1184 - val_accuracy: 0.9694
# Epoch 65/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.0905 - accuracy: 0.9687 - val_loss: 0.1547 - val_accuracy: 0.9632
# Epoch 66/300
# 204/204 [==============================] - 46s 226ms/step - loss: 0.1084 - accuracy: 0.9615 - val_loss: 0.1194 - val_accuracy: 0.9706
# Epoch 67/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1096 - accuracy: 0.9603 - val_loss: 0.1253 - val_accuracy: 0.9663
# Epoch 68/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.0864 - accuracy: 0.9686 - val_loss: 0.1224 - val_accuracy: 0.9632
# Epoch 69/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1006 - accuracy: 0.9660 - val_loss: 0.1428 - val_accuracy: 0.9589
# Epoch 70/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1020 - accuracy: 0.9652 - val_loss: 0.1116 - val_accuracy: 0.9688
# Epoch 71/300
# 204/204 [==============================] - 46s 226ms/step - loss: 0.0941 - accuracy: 0.9684 - val_loss: 0.1081 - val_accuracy: 0.9743
# Epoch 72/300
# 204/204 [==============================] - 47s 228ms/step - loss: 0.1014 - accuracy: 0.9646 - val_loss: 0.1553 - val_accuracy: 0.9596
# Epoch 73/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1003 - accuracy: 0.9638 - val_loss: 0.1052 - val_accuracy: 0.9730
# Epoch 74/300
# 204/204 [==============================] - 47s 228ms/step - loss: 0.0911 - accuracy: 0.9698 - val_loss: 0.1432 - val_accuracy: 0.9596
# Epoch 75/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.0810 - accuracy: 0.9693 - val_loss: 0.1660 - val_accuracy: 0.9516
# Epoch 76/300
# 204/204 [==============================] - 47s 230ms/step - loss: 0.0810 - accuracy: 0.9723 - val_loss: 0.1270 - val_accuracy: 0.9718
# Epoch 77/300
# 204/204 [==============================] - 47s 229ms/step - loss: 0.0922 - accuracy: 0.9681 - val_loss: 0.1217 - val_accuracy: 0.9694
# Epoch 78/300
# 204/204 [==============================] - 47s 230ms/step - loss: 0.0920 - accuracy: 0.9686 - val_loss: 0.1287 - val_accuracy: 0.9700
# Epoch 79/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.1028 - accuracy: 0.9625 - val_loss: 0.1157 - val_accuracy: 0.9718
# Epoch 80/300
# 204/204 [==============================] - 47s 229ms/step - loss: 0.0825 - accuracy: 0.9741 - val_loss: 0.1377 - val_accuracy: 0.9632
# Epoch 81/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.0887 - accuracy: 0.9697 - val_loss: 0.1314 - val_accuracy: 0.9663
# Epoch 82/300
# 204/204 [==============================] - 46s 227ms/step - loss: 0.0755 - accuracy: 0.9724 - val_loss: 0.1261 - val_accuracy: 0.9669
# Epoch 83/300
# 204/204 [==============================] - 47s 231ms/step - loss: 0.0739 - accuracy: 0.9761 - val_loss: 0.1565 - val_accuracy: 0.9589
# train:
#  [[1512    0    0]
#  [   0 3140    0]
#  [   1    0 1872]]
# test:
#  [[353   8  10]
#  [ 11 761  11]
#  [  4   0 474]]
# test:0.973039
# train:0.999847
# (0.9998467432950191, 0.9730392156862745)

# %%
test_model(model,feature2[:,[0,1,4,5],:,:],Y2,False)
# Out:
# acc:0.657561
# [[217 144 111]
#  [151 768  69]
#  [ 98 129 363]]
# 0.6575609756097561
