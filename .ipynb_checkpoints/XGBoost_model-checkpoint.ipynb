# %%
from lib.config import Config_f
from lib.data_set import Features
from lib.model import SimpleModel
from lib import utils

# %%
import imp
imp.reload(utils)
# Out:
# <module 'utils' from 'E:\\Document\\jupyter\\Master Thesis\\utils.py'>

# %%
import ctypes
import pandas as pd
import numpy as np
import pywt
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,f_classif,chi2,mutual_info_classif,VarianceThreshold,RFE,SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

import xgboost as xgb
from xgboost import plot_importance

# %% [markdown]
# ## File name read

# %%
# read file name of data with various Labels
df = pd.read_csv('./useful_data_label.csv',index_col=0) 
# read file name of data with only label 0
df2 = pd.read_csv('./unuseful_data_label.csv',index_col=0)
# read some of the data with only label 0
df3 = pd.read_csv('./data/file_name.txt',header=None)
player = ctypes.windll.kernel32

ind = df2.iloc[1].isna()
files = np.concatenate([np.array(df.columns),np.array('normal/'+df2.columns[ind])])

# %% [markdown]
# ## Configuration

# %%
# Override the base class of Config and Features for XGBoost Model
class XGB_Config(Config_f):
    NAME = 'XGBoost'
    NUM_CLASSES = 2

    CLASS_WEIGHTS = None
    FN_LP = 300
    DETREND_LAMBDA = 50
    TEST_FILES = files[[6,30,31,32,33,34,35]]
    
    # XGBoost parameters
    N_EST = 500
    MAX_DEPTH = 3
    LR = 0.1
    SUBSAMPLE = 0.9
    REG_LAMBDA = 25
    
class XGB_dataset(Features):
    
    def __init__(self,config):
        super(XGB_dataset,self).__init__(config)
        self.config = config

# %%
# Generate XGBoost configuration
config = XGB_Config()
config.display()
# Out:
# Configurations:
# BINS                           3
# CHANNELS                       ['LEFT_TA', 'LEFT_TS', 'LEFT_BF', 'LEFT_RF', 'RIGHT_TA', 'RIGHT_TS', 'RIGHT_BF', 'RIGHT_RF']
# CLASS_WEIGHTS                  None
# DETREND_LAMBDA                 50
# FEATURES_LIST                  ['IEMG', 'SSI', 'WL', 'ZC', 'ku', 'SSC', 'skew', 'Acti', 'AR', 'HIST', 'MDF', 'MNF', 'mDWT']
# FN_LP                          300
# LEVEL_DWT                      3
# LR                             0.1
# MAX_DEPTH                      3
# NAME                           XGBoost
# NUM_CLASSES                    2
# NUM_MF                         3
# N_ENV                          20
# N_EST                          500
# RANGES                         (-3, 3)
# RECT                           False
# REG_LAMBDA                     25
# SAME_LABEL                     True
# SCALE                          True
# SHUFFLE                        True
# STEP_SIZE                      512
# SUBSAMPLE                      0.9
# TEST_FILES                     ['G08_FoG_1_trial_1_emg.csv' 'normal/G09_Walking_trial_2_emg.csv'
#  'normal/G09_Walking_trial_4_emg.csv' 'normal/G09_Walking_trial_6_emg.csv'
#  'normal/G11_Walking_trial_2_emg.csv' 'normal/G11_Walking_trial_4_emg.csv'
#  'normal/P231_M050_A_Walking_trial_2_emg.csv']
# THRESHOLD_SSC                  0.01
# THRESHOLD_WAMP                 1
# THRESHOLD_ZC                   0.0
# TRAIN_SET_RATIO                0.8
# WAVELET_DWT                    db7
# WINDOW_SIZE                    1024

# %% [markdown]
# ## Data generate

# %%
data = XGB_dataset(config)

# %%
# Choose features to use
data.feature_list = ['IEMG', 'SSI', 'WL', 'ZC', 'ku', 'SSC', 'skew', 'Acti', 'AR', 'HIST', 'MF','MDF', 'MNF', 'mDWT']
data.num_mf = 10

# Load data from files
data.load_data(files)

# Extract features from data
data.extract_features()

X_train,Y_train,_ = data.train_set
X_valid,Y_valid,_ = data.valid_set
X_test, Y_test, _ = data.test_set
# Out:
# skip
# skip
# 3/174: G06_FoG_trial_1_emg.csv
# 4/174: G06_FoG_trial_2_emg.csv
# 5/174: G06_FoG_trial_3_emg.csv
# 6/174: G07_Freezing_Trial1_trial_1_emg.csv
# 7/174: G08_FoG_1_trial_1_emg.csv
# 8/174: G08_FoG_2_trial_1_emg.csv
# 9/174: G11_FoG_trial_1_emg.csv
# 10/174: G11_FoG_trial_2_emg.csv
# 11/174: P379_M050_2_OFF_A_FoG_trial_1_emg.csv
# 12/174: P379_M050_2_OFF_A_FoG_trial_2_emg.csv
# 13/174: P379_M050_2_OFF_A_FoG_trial_3_emg.csv
# 14/174: P379_M050_2_OFF_B_FoG_trial_1_emg.csv
# 15/174: P379_M050_2_OFF_B_FoG_trial_2_emg.csv
# 16/174: P379_M050_2_OFF_B_FoG_trial_3_emg.csv
# 17/174: P551_M050_2_A_FoG_trial_1_emg.csv
# 18/174: P551_M050_2_B_FoG_trial_1_emg.csv
# 19/174: P551_M050_2_B_FoG_trial_2_emg.csv
# 20/174: P812_M050_2_B_FoG_trial_1_emg.csv
# 21/174: P812_M050_2_B_FoG_trial_2_emg.csv
# 22/174: normal/G02_Walking_trial_1_emg.csv
# 23/174: normal/G03_Walking_trial_1_emg.csv
# 24/174: normal/G03_Walking_trial_2_emg.csv
# 25/174: normal/G05_Walking_struct_fixed_trial_1_emg.csv
# 26/174: normal/G05_Walking_struct_fixed_trial_2_emg.csv
# 27/174: normal/G05_Walking_struct_fixed_trial_3_emg.csv
# 28/174: normal/G09_FoG_trial_1_emg.csv
# 29/174: normal/G09_FoG_trial_2_emg.csv
# 30/174: normal/G09_FoG_trial_3_emg.csv
# 31/174: normal/G09_Walking_trial_2_emg.csv
# 32/174: normal/G09_Walking_trial_4_emg.csv
# 33/174: normal/G09_Walking_trial_6_emg.csv
# 34/174: normal/G11_Walking_trial_2_emg.csv
# 35/174: normal/G11_Walking_trial_4_emg.csv
# 36/174: normal/P231_M050_A_Walking_trial_2_emg.csv
# 37/174: normal/P231_M050_A_Walking_trial_4_emg.csv
# 38/174: normal/P231_M050_A_Walking_trial_6_emg.csv
# 39/174: normal/P231_M050_B_Walking_trial_2_emg.csv
# 40/174: normal/P231_M050_B_Walking_trial_4_emg.csv
# 41/174: normal/P231_M050_B_Walking_trial_6_emg.csv
# 42/174: normal/P231_M100_2_A_FoG_trial_3_emg.csv
# 43/174: normal/P231_M100_2_A_Walking_trial_4_emg.csv
# 44/174: normal/P231_M100_2_A_Walking_trial_6_emg.csv
# 138/174: normal/P876_M100_B_Walking_trial_6_emg.csv
# 139/174: normal/P940_M050_2_A_FoG_trial_3_emg.csv
# 140/174: normal/P940_M050_2_A_FoG_trial_4_emg.csv
# 141/174: normal/P940_M050_2_A_Walking_trial_2_emg.csv
# 142/174: normal/P940_M050_2_B_FoG_trial_1_emg.csv
# 143/174: normal/P940_M050_2_B_Walking_trial_2_emg.csv
# 144/174: normal/P940_M050_2_B_Walking_trial_4_emg.csv
# 145/174: normal/P940_M050_2_B_Walking_trial_6_emg.csv
# 146/174: normal/P940_M050_A_FoG_trial_2_emg.csv
# 147/174: normal/P940_M050_A_FoG_trial_3_emg.csv
# 148/174: normal/P940_M050_A_Walking_trial_2_emg.csv
# 149/174: normal/P940_M050_A_Walking_trial_4_emg.csv
# 150/174: normal/P940_M050_A_Walking_trial_6_emg.csv
# 151/174: normal/P940_M050_B_FoG_trial_1_emg.csv
# 152/174: normal/P940_M050_B_FoG_trial_2_emg.csv
# 153/174: normal/P940_M050_B_FoG_trial_3_emg.csv
# 154/174: normal/P940_M050_B_Walking_trial_2_emg.csv
# 155/174: normal/P940_M050_B_Walking_trial_4_emg.csv
# 156/174: normal/P940_M050_B_Walking_trial_6_emg.csv
# 157/174: normal/P940_M100_A_FoG_trial_1_emg.csv
# 158/174: normal/P940_M100_A_FoG_trial_2_emg.csv
# 159/174: normal/P940_M100_A_FoG_trial_3_emg.csv
# 160/174: normal/P940_M100_A_Walking_trial_2_emg.csv
# 161/174: normal/P940_M100_A_Walking_trial_4_emg.csv
# 162/174: normal/P940_M100_A_Walking_trial_6_emg.csv
# 163/174: normal/P940_M100_B_FoG_trial_2_emg.csv
# 164/174: normal/P940_M100_B_FoG_trial_3_emg.csv
# 165/174: normal/P940_M100_B_Walking_2_trial_2_emg.csv
# 166/174: normal/P940_M100_B_Walking_2_trial_6_emg.csv
# 167/174: normal/P940_MSham_A_FoG_trial_1_emg.csv
# 168/174: normal/P940_MSham_A_FoG_trial_3_emg.csv
# 169/174: normal/P940_MSham_A_Walking_trial_2_emg.csv
# 170/174: normal/P940_MSham_A_Walking_trial_4_emg.csv
# 171/174: normal/P940_MSham_A_Walking_trial_6_emg.csv
# 172/174: normal/P940_MSham_B_Walking_trial_2_emg.csv
# 173/174: normal/P940_MSham_B_Walking_trial_4_emg.csv
# 174/174: normal/P940_MSham_B_Walking_trial_6_emg.csv
# threshold_WAMP:1.0, threshold_ZC:0.0, threshold_SSC:0.0, bins:3, ranges:(-3,3), num_mf:10, wavelet: db7, level: 3
# ['IEMG', 'SSI', 'WL', 'ZC', 'ku', 'SSC', 'skew', 'Acti', 'AR', 'HIST', 'MF', 'MDF', 'MNF', 'mDWT']
# threshold_WAMP:1.0, threshold_ZC:0.0, threshold_SSC:0.0, bins:3, ranges:(-3,3), num_mf:10, wavelet: db7, level: 3
# ['IEMG', 'SSI', 'WL', 'ZC', 'ku', 'SSC', 'skew', 'Acti', 'AR', 'HIST', 'MF', 'MDF', 'MNF', 'mDWT']
# threshold_WAMP:1.0, threshold_ZC:0.0, threshold_SSC:0.0, bins:3, ranges:(-3,3), num_mf:10, wavelet: db7, level: 3
# ['IEMG', 'SSI', 'WL', 'ZC', 'ku', 'SSC', 'skew', 'Acti', 'AR', 'HIST', 'MF', 'MDF', 'MNF', 'mDWT']

# %% [markdown]
# ## Model

# %%
# Override base class of SimpleMode for XGBoost
class XGB_Model(SimpleModel):
    
    def build(self,config):
        
        if config.NUM_CLASSES > 2:
            model = xgb.XGBClassifier(max_depth=config.MAX_DEPTH, 
                              learning_rate=config.LR, 
                              n_estimators=config.N_EST, 
                              objective='multi:softmax',
                              num_calss=config.NUM_CLASSES,
                              subsample=config.SUBSAMPLE,
                              reg_lambda = config.REG_LAMBDA,
                              #reg_alpha = 3,
                             )
        else:
            model = xgb.XGBClassifier(max_depth=config.MAX_DEPTH, 
                              learning_rate=config.LR, 
                              n_estimators=config.N_EST, 
                              objective='binary:logistic',
                              scale_pos_weight = config.CLASS_WEIGHTS,
                              subsample=config.SUBSAMPLE,
                              reg_lambda = config.REG_LAMBDA,
                              #reg_alpha = 3,
                             )
        
        if config.CLASS_WEIGHTS != None:
            print('Using class weights: 1:',config.CLASS_WEIGHTS)
        
        return model
    
    def train(self, train_dataset, val_dataset, transformer=None):
        
        self.X_train = train_dataset[0]
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(train_dataset[0])
        
        scaler.fit(np.concatenate([train_dataset[0],val_dataset[0]]))
        X_val = scaler.transform(val_dataset[0])
        
        if transformer != None:
            self.transformer = transformer
            self.transformer.fit(X_train,train_dataset[1])
            X_train = self.transformer.transform(X_train)
            X_val = self.transformer.transform(X_val)
        else:
            self.transformer = None
         
        metric = 'merror' if self.config.NUM_CLASSES > 2 else 'error'
            
        eval_set=[(X_train,train_dataset[1]),(X_val,val_dataset[1])]
        self.simple_model.fit(X_train, train_dataset[1],eval_metric=[metric],
                              eval_set=eval_set,early_stopping_rounds=30)

# %% [markdown]
# ## Data split

# %%
# data split and processing for model
class_id = [1,2,6]
binary = False
x_train,y_train,x_valid,y_valid,x_test,y_test = utils.data_split((X_train,X_valid,X_test),
                                                                 (Y_train,Y_valid,Y_test),
                                                                 class_id,
                                                                 binary,
                                                                 random_state = 555)

# %% [markdown]
# ## Model training

# %%
if binary:
    config.CLASS_WEIGHTS = 5
    config.NUM_CLASSES = 2
else:
    config.CLASS_WEIGHTS = None
    config.NUM_CLASSES = len(class_id)

# Generate XGBoost Model
xgb_model = XGB_Model('XGB',config,'./model/XGB/')

# %%
pca = PCA(n_components=150,copy=True)
sfm = SelectFromModel(GradientBoostingClassifier(),max_features=80)
rfe = RFE(estimator=LogisticRegression(max_iter=10000), n_features_to_select=100)
vt = VarianceThreshold(threshold=0.01)

xgb_model.train((x_train,y_train),(x_valid,y_valid),rfe)
# Out:
# [23:30:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { num_calss } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-merror:0.16449	validation_1-merror:0.20670
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 30 rounds.
# [1]	validation_0-merror:0.14392	validation_1-merror:0.18436
# [2]	validation_0-merror:0.14953	validation_1-merror:0.17877
# [3]	validation_0-merror:0.13832	validation_1-merror:0.18436
# [4]	validation_0-merror:0.13084	validation_1-merror:0.20670
# [5]	validation_0-merror:0.13271	validation_1-merror:0.19553
# [6]	validation_0-merror:0.13084	validation_1-merror:0.19553
# [7]	validation_0-merror:0.12150	validation_1-merror:0.18994
# [8]	validation_0-merror:0.12150	validation_1-merror:0.19553
# [9]	validation_0-merror:0.11963	validation_1-merror:0.19553
# [10]	validation_0-merror:0.12150	validation_1-merror:0.17877
# [11]	validation_0-merror:0.11589	validation_1-merror:0.18994
# [12]	validation_0-merror:0.11215	validation_1-merror:0.18436
# [13]	validation_0-merror:0.11402	validation_1-merror:0.18436
# [14]	validation_0-merror:0.11215	validation_1-merror:0.17877
# [15]	validation_0-merror:0.11402	validation_1-merror:0.18436
# [16]	validation_0-merror:0.11215	validation_1-merror:0.17877
# [17]	validation_0-merror:0.11028	validation_1-merror:0.17877
# [18]	validation_0-merror:0.10654	validation_1-merror:0.17877
# [19]	validation_0-merror:0.10654	validation_1-merror:0.17877
# [20]	validation_0-merror:0.10467	validation_1-merror:0.17877
# [21]	validation_0-merror:0.10280	validation_1-merror:0.17877
# [22]	validation_0-merror:0.10467	validation_1-merror:0.17318
# [23]	validation_0-merror:0.10093	validation_1-merror:0.17318
# [24]	validation_0-merror:0.09346	validation_1-merror:0.17318
# [25]	validation_0-merror:0.08411	validation_1-merror:0.16201
# [26]	validation_0-merror:0.08785	validation_1-merror:0.16760
# [27]	validation_0-merror:0.08598	validation_1-merror:0.16760
# [28]	validation_0-merror:0.08598	validation_1-merror:0.16201
# [29]	validation_0-merror:0.08224	validation_1-merror:0.17318
# [30]	validation_0-merror:0.08037	validation_1-merror:0.16201
# [31]	validation_0-merror:0.07851	validation_1-merror:0.15643
# [32]	validation_0-merror:0.07477	validation_1-merror:0.14525
# [33]	validation_0-merror:0.07664	validation_1-merror:0.13967
# [34]	validation_0-merror:0.07290	validation_1-merror:0.13967
# [35]	validation_0-merror:0.07290	validation_1-merror:0.13967
# [36]	validation_0-merror:0.07290	validation_1-merror:0.13967
# [37]	validation_0-merror:0.06916	validation_1-merror:0.13967
# [38]	validation_0-merror:0.06729	validation_1-merror:0.13967
# [39]	validation_0-merror:0.06168	validation_1-merror:0.13967
# [40]	validation_0-merror:0.05794	validation_1-merror:0.13967
# [41]	validation_0-merror:0.05794	validation_1-merror:0.13967
# [42]	validation_0-merror:0.05607	validation_1-merror:0.14525
# [43]	validation_0-merror:0.05607	validation_1-merror:0.13967
# [44]	validation_0-merror:0.05607	validation_1-merror:0.13967
# [45]	validation_0-merror:0.05421	validation_1-merror:0.14525
# [46]	validation_0-merror:0.05421	validation_1-merror:0.14525
# [47]	validation_0-merror:0.05421	validation_1-merror:0.14525
# [48]	validation_0-merror:0.04860	validation_1-merror:0.13967
# [49]	validation_0-merror:0.04486	validation_1-merror:0.14525
# [50]	validation_0-merror:0.04486	validation_1-merror:0.13967
# [51]	validation_0-merror:0.04112	validation_1-merror:0.13967
# [52]	validation_0-merror:0.04112	validation_1-merror:0.13967
# [53]	validation_0-merror:0.03925	validation_1-merror:0.13967
# [54]	validation_0-merror:0.03925	validation_1-merror:0.13967
# [55]	validation_0-merror:0.03738	validation_1-merror:0.13967
# [56]	validation_0-merror:0.03551	validation_1-merror:0.13408
# [57]	validation_0-merror:0.03551	validation_1-merror:0.13408
# [58]	validation_0-merror:0.03551	validation_1-merror:0.13408
# [59]	validation_0-merror:0.03551	validation_1-merror:0.13967
# [60]	validation_0-merror:0.03551	validation_1-merror:0.13967
# [61]	validation_0-merror:0.03738	validation_1-merror:0.13967
# [62]	validation_0-merror:0.03738	validation_1-merror:0.13408
# [63]	validation_0-merror:0.03738	validation_1-merror:0.13967
# [64]	validation_0-merror:0.03551	validation_1-merror:0.13967
# [65]	validation_0-merror:0.03551	validation_1-merror:0.13408
# [66]	validation_0-merror:0.03551	validation_1-merror:0.13408
# [67]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [68]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [69]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [70]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [71]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [72]	validation_0-merror:0.03178	validation_1-merror:0.13408
# [73]	validation_0-merror:0.02991	validation_1-merror:0.13408
# [74]	validation_0-merror:0.02991	validation_1-merror:0.13408
# [75]	validation_0-merror:0.02991	validation_1-merror:0.13408
# [76]	validation_0-merror:0.02991	validation_1-merror:0.13967
# [77]	validation_0-merror:0.02804	validation_1-merror:0.13967
# [78]	validation_0-merror:0.02617	validation_1-merror:0.13967
# [79]	validation_0-merror:0.02430	validation_1-merror:0.13967
# [80]	validation_0-merror:0.02430	validation_1-merror:0.13967
# [81]	validation_0-merror:0.02430	validation_1-merror:0.13408
# [82]	validation_0-merror:0.02430	validation_1-merror:0.13408
# [83]	validation_0-merror:0.02243	validation_1-merror:0.13408
# [84]	validation_0-merror:0.02243	validation_1-merror:0.13408
# [85]	validation_0-merror:0.01869	validation_1-merror:0.12849
# [86]	validation_0-merror:0.01869	validation_1-merror:0.12849
# [87]	validation_0-merror:0.01869	validation_1-merror:0.12849
# [88]	validation_0-merror:0.01869	validation_1-merror:0.12849
# [89]	validation_0-merror:0.01869	validation_1-merror:0.13408
# [90]	validation_0-merror:0.01682	validation_1-merror:0.12849
# [91]	validation_0-merror:0.01682	validation_1-merror:0.12849
# [92]	validation_0-merror:0.01682	validation_1-merror:0.12849
# [93]	validation_0-merror:0.01682	validation_1-merror:0.12849
# [94]	validation_0-merror:0.01495	validation_1-merror:0.12849
# [95]	validation_0-merror:0.01308	validation_1-merror:0.13408
# [96]	validation_0-merror:0.01121	validation_1-merror:0.13408
# [97]	validation_0-merror:0.01121	validation_1-merror:0.13408
# [98]	validation_0-merror:0.01121	validation_1-merror:0.12849
# [99]	validation_0-merror:0.00935	validation_1-merror:0.13408
# [100]	validation_0-merror:0.00935	validation_1-merror:0.13408
# [101]	validation_0-merror:0.00935	validation_1-merror:0.13408
# [102]	validation_0-merror:0.00935	validation_1-merror:0.13408
# [103]	validation_0-merror:0.00935	validation_1-merror:0.13408
# [104]	validation_0-merror:0.00748	validation_1-merror:0.12291
# [105]	validation_0-merror:0.00748	validation_1-merror:0.12291
# [106]	validation_0-merror:0.00748	validation_1-merror:0.12291
# [107]	validation_0-merror:0.00748	validation_1-merror:0.11732
# [108]	validation_0-merror:0.00748	validation_1-merror:0.11732
# [109]	validation_0-merror:0.00748	validation_1-merror:0.11732
# [110]	validation_0-merror:0.00374	validation_1-merror:0.11732
# [111]	validation_0-merror:0.00374	validation_1-merror:0.11732
# [112]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [113]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [114]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [115]	validation_0-merror:0.00374	validation_1-merror:0.11173
# [116]	validation_0-merror:0.00374	validation_1-merror:0.11732
# [117]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [118]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [119]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [120]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [121]	validation_0-merror:0.00374	validation_1-merror:0.11732
# [122]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [123]	validation_0-merror:0.00374	validation_1-merror:0.11732
# [124]	validation_0-merror:0.00374	validation_1-merror:0.12291
# [125]	validation_0-merror:0.00374	validation_1-merror:0.11173
# [126]	validation_0-merror:0.00374	validation_1-merror:0.11173
# [127]	validation_0-merror:0.00374	validation_1-merror:0.11173
# [128]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [129]	validation_0-merror:0.00187	validation_1-merror:0.11732
# [130]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [131]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [132]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [133]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [134]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [135]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [136]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [137]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [138]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [139]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [140]	validation_0-merror:0.00187	validation_1-merror:0.11173
# [141]	validation_0-merror:0.00000	validation_1-merror:0.11173
# [142]	validation_0-merror:0.00000	validation_1-merror:0.11173
# [143]	validation_0-merror:0.00000	validation_1-merror:0.11173
# [144]	validation_0-merror:0.00000	validation_1-merror:0.11173
# [145]	validation_0-merror:0.00000	validation_1-merror:0.11173
# Stopping. Best iteration:
# [115]	validation_0-merror:0.00374	validation_1-merror:0.11173

# %% [markdown]
# ## Model evaluation

# %%
acc_train,cm_train = xgb_model.model_metrics(x_train,y_train)
acc_valid,cm_valid = xgb_model.model_metrics(x_valid,y_valid)
acc_test,cm_test = xgb_model.model_metrics(x_test,y_test)
print('acc_train: %f\nconfusion_matrix:\n'%acc_train,cm_train)
print('acc_valid: %f\nconfusion_matrix:\n'%acc_valid,cm_valid)
print('acc_test: %f\nconfusion_matrix:\n'%acc_test,cm_test)
# Out:
# acc_train: 0.996262
# confusion_matrix:
#  [[120   2   0]
#  [  0 257   0]
#  [  0   0 156]]
# acc_valid: 0.888268
# confusion_matrix:
#  [[27  2  2]
#  [ 6 89  3]
#  [ 6  1 43]]
# acc_test: 0.741294
# confusion_matrix:
#  [[46  5  1]
#  [28 29  0]
#  [17  1 74]]
