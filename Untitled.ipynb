# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
import data_processing as dp
from scipy import signal
from scipy.stats import skew
import seaborn as sns
import matplotlib.pyplot as plt
import pywt
import os
import time
import h5py
from itertools import combinations

# %%
import imp
imp.reload(dp)
# Out:
# <module 'data_processing' from 'E:\\Document\\jupyter\\Master Thesis\\data_processing.py'>

# %%
# read file name of data with various Labels
df = pd.read_csv('./useful_data_label.csv',index_col=0) 
# read file name of data with only label 0
df2 = pd.read_csv('./unuseful_data_label.csv',index_col=0)
# read some of the data with only label 0
df3 = pd.read_csv('./data/file_name.txt',header=None)

# %%
# read the data and labels of df2 or df3
sc = StandardScaler()
#sc = MinMaxScaler()
ind = df2.iloc[1].isna()
#files = np.concatenate([np.array(df.columns),np.array('正常/'+df2.columns[ind])])
files = np.array(df.columns)
N = len(files)
#sc = StandardScaler(with_mean=False)
width = 256
stride = 64
start = time.time()
i = 0
X = []
Y = []
X2 = []
Y2 = []
F = []
F2 = []
for file in files:
    #if file in np.array(df3.loc[:,0]):
    #    continue
    i += 1
    emg_data = pd.read_csv('./data/'+file)
    #emg_data.iloc[:,3:] = 
    emg_data = emg_data.dropna().reset_index(drop=True)
    #emg_data.iloc[:,3:]=normalize(emg_data.iloc[:,3:])
    #emg_data.iloc[:,3:] = sc.fit_transform(emg_data.iloc[:,3:])
    fn = 5
    wn=2*fn/1000
    fn1 = 350
    wn1 = 2*fn1/1000
    #b, a = signal.butter(4, [wn,wn1], 'bandpass')
    b, a = signal.butter(4, [wn], 'highpass')
    for j in ['LEFT_TA','LEFT_TS','LEFT_BF','LEFT_RF','RIGHT_TA','RIGHT_TS','RIGHT_BF','RIGHT_RF']:
        emg_data.loc[:,j] = signal.filtfilt(b, a, emg_data.loc[:,j])
    x,y = dp.generate_window_slide_data(emg_data,width=width,
                                        stride=stride,
                                        scaler=True,
                                        same_label=True)
    #x=np.abs(x)
    #x=dp.lowpass_filter(x,300)
    ind1 = []
    ind2 = []
    l = len(y)
    for j in set(y):
        ind = np.where(y == j)[0].tolist()
        l_t = len(ind)
        ind1 += ind[:int(l_t*0.8)]
        ind2 += ind[int(l_t*0.8):]
        #l_t = len(label[ind])
        #feature1 += feature[ind][:int(l_t*0.8)].tolist()
        #label1 += label[ind][:int(l_t*0.8)].tolist()
        #feature2 += feature[ind][int(l_t*0.8):].tolist()
        #label2 += label[ind][int(l_t*0.8):].tolist()
    l1 = len(ind1)
    l2 = len(ind2)

    fi = [file]*len(x)
    X += x[ind1].tolist()
    Y += y[ind1].tolist()
    F += fi
    X2 += x[ind2].tolist()
    Y2 += y[ind2].tolist()
    F2 += fi
    print('%d/%d: '%(i,N)+file)
    
X = np.array(X)
Y = np.array(Y)
X2 = np.array(X2)
Y2 = np.array(Y2)
end = time.time()
duration = end-start
print('Duration: %f'%(duration))
# Out:
# 1/21: G04_FoG_trial_1_emg.csv
# 2/21: G04_FoG_trial_2_emg.csv
# 3/21: G06_FoG_trial_1_emg.csv
# 4/21: G06_FoG_trial_2_emg.csv
# 5/21: G06_FoG_trial_3_emg.csv
# 6/21: G07_Freezing_Trial1_trial_1_emg.csv
# 7/21: G08_FoG_1_trial_1_emg.csv
# 8/21: G08_FoG_2_trial_1_emg.csv
# 9/21: G11_FoG_trial_1_emg.csv
# 10/21: G11_FoG_trial_2_emg.csv
# 11/21: P379_M050_2_OFF_A_FoG_trial_1_emg.csv
# 12/21: P379_M050_2_OFF_A_FoG_trial_2_emg.csv
# 13/21: P379_M050_2_OFF_A_FoG_trial_3_emg.csv
# 14/21: P379_M050_2_OFF_B_FoG_trial_1_emg.csv
# 15/21: P379_M050_2_OFF_B_FoG_trial_2_emg.csv
# 16/21: P379_M050_2_OFF_B_FoG_trial_3_emg.csv
# 17/21: P551_M050_2_A_FoG_trial_1_emg.csv
# 18/21: P551_M050_2_B_FoG_trial_1_emg.csv
# 19/21: P551_M050_2_B_FoG_trial_2_emg.csv
# 20/21: P812_M050_2_B_FoG_trial_1_emg.csv
# 21/21: P812_M050_2_B_FoG_trial_2_emg.csv
# Duration: 30.657578

# %%
import tensorflow as tf
from tensorflow.keras import layers,Model,callbacks,regularizers,models
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split,cross_validate
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder,normalize,MinMaxScaler
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE,BorderlineSMOTE,ADASYN,SVMSMOTE

# %%
def train_model(model,feature,y,binary=True,file=None):
    if binary:
        ind = ((y==0)|(y==1)|(y==2)|(y==6))
        #ind1 = ((y==4)|(y==1)|(y==2)|(y==3)|(y==6))
        y_01 = y[ind].copy()
        ind1 = ((y_01==1)|(y_01==2)|(y_01==6))
        y_01[ind1] = 1
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:1,1:5}
    else:
        ind = ((y==1)|(y==2)|(y==6))
        #ind = ((y==1)|(y==6))
        y_01 = y[ind].copy()
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:5,1:1,2:1}#{0:2,1:1,2:10,3:2}
    x_full,x_test,y_full,y_test = train_test_split(np.array(feature)[ind,:],y_01,
                                                   test_size=0.2,
                                                   random_state=123,
                                                   shuffle=True)
    x_train,x_valid,y_train,y_valid = train_test_split(x_full,y_full,
                                                       test_size=0.25,
                                                       random_state=555,
                                                       shuffle=True)
    
    #sm = BorderlineSMOTE(random_state=50,kind='borderline-2')
    #sm = SMOTE(random_state=50)
    #print(y_full.shape)
    #x_full,y_full = sm.fit_resample(x_full,y_full)
    #print(y_full_n.shape)
    sc = StandardScaler(with_mean=True)
    #sc = MinMaxScaler()
    #x_train = sc.fit_transform(x_full)
    pca = PCA(n_components=100)
    #x_train = pca.fit_transform(x_train)
    #x_valid = sc.transform(x_valid)
    #x_test = sc.transform(x_test)
    #x_test = pca.transform(x_test)
    x_train = x_full
    
    early_stopping = callbacks.EarlyStopping(patience = 10,
                                             monitor = 'val_loss', 
                                             restore_best_weights=True)
    history = model.fit(x_train,y_full,validation_data=(x_test,y_test),
                        epochs=100,batch_size=32,class_weight=cw,
                        callbacks=[early_stopping],
                        shuffle=True)
    
    if binary:
        y_pred_t=model.predict(x_test)
        test = metrics.accuracy_score(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1))
        #test = metrics.accuracy_score(y_test,y_pred_t>0.5)
        
        #y_pred_v=model.predict(x_valid)
        #valid = metrics.accuracy_score(y_valid,np.argmax(y_pred_v,axis=1))
        y_pred_ta=model.predict(x_train)
        train = metrics.accuracy_score(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1))
        #train = metrics.accuracy_score(y_full,y_pred_ta>0.5)
        
        print('train: \n',metrics.confusion_matrix(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1)))
        #print('valid: \n',metrics.confusion_matrix(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1)))
        print('test: \n',metrics.confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1)))
        
        #print('train: \n',metrics.confusion_matrix(y_full,y_pred_ta>0.5))
        #print('test: \n',metrics.confusion_matrix(y_test,y_pred_t>0.5))

    else:
        y_pred_t=model.predict(x_test)
        test = metrics.accuracy_score(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1))
        #y_pred_v=model.predict(x_valid)
        #valid = metrics.accuracy_score(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1))
        y_pred_ta=model.predict(x_train)
        train = metrics.accuracy_score(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1))        
        print('train: \n',metrics.confusion_matrix(np.argmax(y_full,axis=1),np.argmax(y_pred_ta,axis=1)))
        #print('valid: \n',metrics.confusion_matrix(np.argmax(y_valid,axis=1),np.argmax(y_pred_v,axis=1)))
        print('test: \n',metrics.confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred_t,axis=1)))
    print('test:%f'%test)
    #print('valid:%f'%valid)
    print('train:%f'%train)
    if file != None:
        model.save_model(file)
    return train,test,sc,pca

def test_model(model,feature,y,binary=True):
    if binary:
        ind = ((y==0)|(y==1)|(y==2)|(y==3)|(y==4)|(y==6))
        #ind1 = ((y==4)|(y==1)|(y==2)|(y==3)|(y==6))
        y_01 = y[ind].copy()
        ind1 = ((y_01==1)|(y_01==2)|(y_01==6))
        y_01[ind1] = 1
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:1,1:5}
    else:
        ind = ((y==1)|(y==2)|(y==6))
        #ind = ((y==1)|(y==6))
        y_01 = y[ind].copy()
        oc = OneHotEncoder()
        y_01 = oc.fit_transform(np.array(y_01)[:,np.newaxis]).toarray()
        cw = None#{0:5,1:1,2:1}#{0:2,1:1,2:10,3:2}

    #print(y_01)
    #feature=sc.transform(feature[ind])
    feature = feature[ind]
    #feature=pca.transform(feature)
    y_pred=model.predict(feature)
    test = metrics.accuracy_score(np.argmax(y_01,axis=1),np.argmax(y_pred,axis=1))
    #test = metrics.accuracy_score(y_01,y_pred>0.5)
    
    print('acc:%f'%test)
    print(metrics.confusion_matrix(np.argmax(y_01,axis=1),np.argmax(y_pred,axis=1)))
    #print(metrics.confusion_matrix(y_01,y_pred>0.5))
    return test

def sparse_cost_sensitive_loss (y_true,y_pred):
    #cost_matrix = tf.constant([[0,1.,1,1.],
    #              [2,0,5,5],
    #              [1,1,0,1],
    #              [1.,2.,1,0]])
    cost_matrix = tf.constant([[0,2.,2],
                  [1,0,1],
                  [1.0,1.,0]])
    #cost_matrix = tf.constant([[0,1.],
    #              [5.,0]])
    batch_cost_matrix = tf.nn.embedding_lookup(cost_matrix, tf.argmax(y_true,axis=1))
    eps = 1e-6
    probability = tf.clip_by_value(y_pred, eps, 1-eps)
    cost_values = tf.math.log(1-probability)*batch_cost_matrix
    loss = tf.reduce_mean(-tf.reduce_sum(cost_values, axis=1))
    return loss

# %%
import discriminator
import imp
imp.reload(discriminator)
# Out:
# <module 'discriminator' from 'E:\\Document\\jupyter\\Master Thesis\\discriminator.py'>

# %%
args = {'num_steps': 256,
        'channels': 8,
        'conv_activation': 'relu',
        'dropout_rate': 0.2,
        'wavelet_mother': 'db7',
        'wavelet_levels': 2,
        'wavelet_trainable': False,
        'use_mini_batch': False,
        'sliding_window': 10,
        'activation_function': 'tanh',
        'moving_avg_window': 5,
        }

# %%
cric = discriminator.Discriminator(args,training=True)
cric.model.compile(loss = 'categorical_crossentropy' ,optimizer='adam',metrics=['accuracy'])
# Out:
# (None, 256, 8)
# Critic model:
# Model: "functional_51"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_33 (InputLayer)           [(None, 256, 8)]     0
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_65 (TensorF [(None, 256, 8, 1)]  0           input_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_500 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_502 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# low_pass_0.0 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_500[0][
# __________________________________________________________________________________________________
# low_pass_0.1 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_502[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_504 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_407 (TensorF [(None, 128, 2)]     0           low_pass_0.0[0][0]
#                                                                  low_pass_0.1[0][0]
# __________________________________________________________________________________________________
# low_pass_0.2 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_504[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_506 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_409 (TensorF [(None, 128, 3)]     0           tf_op_layer_concat_407[0][0]
#                                                                  low_pass_0.2[0][0]
# __________________________________________________________________________________________________
# low_pass_0.3 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_506[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_508 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_411 (TensorF [(None, 128, 4)]     0           tf_op_layer_concat_409[0][0]
#                                                                  low_pass_0.3[0][0]
# __________________________________________________________________________________________________
# low_pass_0.4 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_508[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_510 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_413 (TensorF [(None, 128, 5)]     0           tf_op_layer_concat_411[0][0]
#                                                                  low_pass_0.4[0][0]
# __________________________________________________________________________________________________
# low_pass_0.5 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_510[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_512 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_415 (TensorF [(None, 128, 6)]     0           tf_op_layer_concat_413[0][0]
#                                                                  low_pass_0.5[0][0]
# __________________________________________________________________________________________________
# low_pass_0.6 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_512[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_514 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_417 (TensorF [(None, 128, 7)]     0           tf_op_layer_concat_415[0][0]
#                                                                  low_pass_0.6[0][0]
# __________________________________________________________________________________________________
# low_pass_0.7 (Conv1D)           (None, 128, 1)       14          tf_op_layer_strided_slice_514[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_419 (TensorF [(None, 128, 8)]     0           tf_op_layer_concat_417[0][0]
#                                                                  low_pass_0.7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_66 (TensorF [(None, 128, 8, 1)]  0           tf_op_layer_concat_419[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_501 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_503 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_517 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_519 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_516 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_518 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# high_pass_0.0 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_501[0][
# __________________________________________________________________________________________________
# high_pass_0.1 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_503[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_505 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# high_pass_1.0 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_517[0][
# __________________________________________________________________________________________________
# high_pass_1.1 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_519[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_521 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# low_pass_1.0 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_516[0][
# __________________________________________________________________________________________________
# low_pass_1.1 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_518[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_520 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_408 (TensorF [(None, 128, 2)]     0           high_pass_0.0[0][0]
#                                                                  high_pass_0.1[0][0]
# __________________________________________________________________________________________________
# high_pass_0.2 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_505[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_507 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_422 (TensorF [(None, 64, 2)]      0           high_pass_1.0[0][0]
#                                                                  high_pass_1.1[0][0]
# __________________________________________________________________________________________________
# high_pass_1.2 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_521[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_523 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_421 (TensorF [(None, 64, 2)]      0           low_pass_1.0[0][0]
#                                                                  low_pass_1.1[0][0]
# __________________________________________________________________________________________________
# low_pass_1.2 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_520[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_522 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_410 (TensorF [(None, 128, 3)]     0           tf_op_layer_concat_408[0][0]
#                                                                  high_pass_0.2[0][0]
# __________________________________________________________________________________________________
# high_pass_0.3 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_507[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_509 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_424 (TensorF [(None, 64, 3)]      0           tf_op_layer_concat_422[0][0]
#                                                                  high_pass_1.2[0][0]
# __________________________________________________________________________________________________
# high_pass_1.3 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_523[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_525 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_423 (TensorF [(None, 64, 3)]      0           tf_op_layer_concat_421[0][0]
#                                                                  low_pass_1.2[0][0]
# __________________________________________________________________________________________________
# low_pass_1.3 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_522[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_524 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_412 (TensorF [(None, 128, 4)]     0           tf_op_layer_concat_410[0][0]
#                                                                  high_pass_0.3[0][0]
# __________________________________________________________________________________________________
# high_pass_0.4 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_509[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_511 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_426 (TensorF [(None, 64, 4)]      0           tf_op_layer_concat_424[0][0]
#                                                                  high_pass_1.3[0][0]
# __________________________________________________________________________________________________
# high_pass_1.4 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_525[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_527 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_425 (TensorF [(None, 64, 4)]      0           tf_op_layer_concat_423[0][0]
#                                                                  low_pass_1.3[0][0]
# __________________________________________________________________________________________________
# low_pass_1.4 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_524[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_526 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_414 (TensorF [(None, 128, 5)]     0           tf_op_layer_concat_412[0][0]
#                                                                  high_pass_0.4[0][0]
# __________________________________________________________________________________________________
# high_pass_0.5 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_511[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_513 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_428 (TensorF [(None, 64, 5)]      0           tf_op_layer_concat_426[0][0]
#                                                                  high_pass_1.4[0][0]
# __________________________________________________________________________________________________
# high_pass_1.5 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_527[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_529 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_427 (TensorF [(None, 64, 5)]      0           tf_op_layer_concat_425[0][0]
#                                                                  low_pass_1.4[0][0]
# __________________________________________________________________________________________________
# low_pass_1.5 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_526[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_528 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_416 (TensorF [(None, 128, 6)]     0           tf_op_layer_concat_414[0][0]
#                                                                  high_pass_0.5[0][0]
# __________________________________________________________________________________________________
# high_pass_0.6 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_513[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_515 ( [(None, 256, 1)]     0           tf_op_layer_Reshape_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_430 (TensorF [(None, 64, 6)]      0           tf_op_layer_concat_428[0][0]
#                                                                  high_pass_1.5[0][0]
# __________________________________________________________________________________________________
# high_pass_1.6 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_529[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_531 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_429 (TensorF [(None, 64, 6)]      0           tf_op_layer_concat_427[0][0]
#                                                                  low_pass_1.5[0][0]
# __________________________________________________________________________________________________
# low_pass_1.6 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_528[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_530 ( [(None, 128, 1)]     0           tf_op_layer_Reshape_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_418 (TensorF [(None, 128, 7)]     0           tf_op_layer_concat_416[0][0]
#                                                                  high_pass_0.6[0][0]
# __________________________________________________________________________________________________
# high_pass_0.7 (Conv1D)          (None, 128, 1)       14          tf_op_layer_strided_slice_515[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_432 (TensorF [(None, 64, 7)]      0           tf_op_layer_concat_430[0][0]
#                                                                  high_pass_1.6[0][0]
# __________________________________________________________________________________________________
# high_pass_1.7 (Conv1D)          (None, 64, 1)        14          tf_op_layer_strided_slice_531[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_431 (TensorF [(None, 64, 7)]      0           tf_op_layer_concat_429[0][0]
#                                                                  low_pass_1.6[0][0]
# __________________________________________________________________________________________________
# low_pass_1.7 (Conv1D)           (None, 64, 1)        14          tf_op_layer_strided_slice_530[0][
# __________________________________________________________________________________________________
# envelope (Lambda)               (None, 256, 8)       0           input_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_420 (TensorF [(None, 128, 8)]     0           tf_op_layer_concat_418[0][0]
#                                                                  high_pass_0.7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_434 (TensorF [(None, 64, 8)]      0           tf_op_layer_concat_432[0][0]
#                                                                  high_pass_1.7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_433 (TensorF [(None, 64, 8)]      0           tf_op_layer_concat_431[0][0]
#                                                                  low_pass_1.7[0][0]
# __________________________________________________________________________________________________
# rfft (Lambda)                   (None, 129, 8)       0           input_33[0][0]
# __________________________________________________________________________________________________
# envelope_fft (Lambda)           (None, 129, 8)       0           envelope[0][0]
# __________________________________________________________________________________________________
# wavelet_concat (Concatenate)    (None, 256, 8)       0           tf_op_layer_concat_420[0][0]
#                                                                  tf_op_layer_concat_434[0][0]
#                                                                  tf_op_layer_concat_433[0][0]
# __________________________________________________________________________________________________
# raw_conv_1 (Conv1D)             (None, 128, 16)      400         input_33[0][0]
# __________________________________________________________________________________________________
# fft_conv_1 (Conv1D)             (None, 65, 16)       400         rfft[0][0]
# __________________________________________________________________________________________________
# fft_env_conv_1 (Conv1D)         (None, 65, 16)       400         envelope_fft[0][0]
# __________________________________________________________________________________________________
# wavelet_conv_1 (Conv1D)         (None, 128, 16)      400         wavelet_concat[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_456 (LeakyReLU)     (None, 128, 16)      0           raw_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_460 (LeakyReLU)     (None, 65, 16)       0           fft_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_464 (LeakyReLU)     (None, 65, 16)       0           fft_env_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_468 (LeakyReLU)     (None, 128, 16)      0           wavelet_conv_1[0][0]
# __________________________________________________________________________________________________
# dropout_424 (Dropout)           (None, 128, 16)      0           leaky_re_lu_456[0][0]
# __________________________________________________________________________________________________
# dropout_428 (Dropout)           (None, 65, 16)       0           leaky_re_lu_460[0][0]
# __________________________________________________________________________________________________
# dropout_432 (Dropout)           (None, 65, 16)       0           leaky_re_lu_464[0][0]
# __________________________________________________________________________________________________
# dropout_436 (Dropout)           (None, 128, 16)      0           leaky_re_lu_468[0][0]
# __________________________________________________________________________________________________
# raw_conv_2 (Conv1D)             (None, 64, 32)       1568        dropout_424[0][0]
# __________________________________________________________________________________________________
# fft_conv_2 (Conv1D)             (None, 33, 32)       1568        dropout_428[0][0]
# __________________________________________________________________________________________________
# fft_env_conv_2 (Conv1D)         (None, 33, 32)       1568        dropout_432[0][0]
# __________________________________________________________________________________________________
# wavelet_conv_2 (Conv1D)         (None, 64, 32)       1568        dropout_436[0][0]
# __________________________________________________________________________________________________
# batch_normalization_342 (BatchN (None, 64, 32)       128         raw_conv_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_345 (BatchN (None, 33, 32)       128         fft_conv_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_348 (BatchN (None, 33, 32)       128         fft_env_conv_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_351 (BatchN (None, 64, 32)       128         wavelet_conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_457 (LeakyReLU)     (None, 64, 32)       0           batch_normalization_342[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_461 (LeakyReLU)     (None, 33, 32)       0           batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_465 (LeakyReLU)     (None, 33, 32)       0           batch_normalization_348[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_469 (LeakyReLU)     (None, 64, 32)       0           batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# dropout_425 (Dropout)           (None, 64, 32)       0           leaky_re_lu_457[0][0]
# __________________________________________________________________________________________________
# dropout_429 (Dropout)           (None, 33, 32)       0           leaky_re_lu_461[0][0]
# __________________________________________________________________________________________________
# dropout_433 (Dropout)           (None, 33, 32)       0           leaky_re_lu_465[0][0]
# __________________________________________________________________________________________________
# dropout_437 (Dropout)           (None, 64, 32)       0           leaky_re_lu_469[0][0]
# __________________________________________________________________________________________________
# raw_conv_3 (Conv1D)             (None, 32, 64)       6208        dropout_425[0][0]
# __________________________________________________________________________________________________
# fft_conv_3 (Conv1D)             (None, 17, 64)       6208        dropout_429[0][0]
# __________________________________________________________________________________________________
# fft_env_conv_3 (Conv1D)         (None, 17, 64)       6208        dropout_433[0][0]
# __________________________________________________________________________________________________
# wavelet_conv_3 (Conv1D)         (None, 32, 64)       6208        dropout_437[0][0]
# __________________________________________________________________________________________________
# batch_normalization_343 (BatchN (None, 32, 64)       256         raw_conv_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_346 (BatchN (None, 17, 64)       256         fft_conv_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_349 (BatchN (None, 17, 64)       256         fft_env_conv_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_352 (BatchN (None, 32, 64)       256         wavelet_conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_458 (LeakyReLU)     (None, 32, 64)       0           batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_462 (LeakyReLU)     (None, 17, 64)       0           batch_normalization_346[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_466 (LeakyReLU)     (None, 17, 64)       0           batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_470 (LeakyReLU)     (None, 32, 64)       0           batch_normalization_352[0][0]
# __________________________________________________________________________________________________
# dropout_426 (Dropout)           (None, 32, 64)       0           leaky_re_lu_458[0][0]
# __________________________________________________________________________________________________
# dropout_430 (Dropout)           (None, 17, 64)       0           leaky_re_lu_462[0][0]
# __________________________________________________________________________________________________
# dropout_434 (Dropout)           (None, 17, 64)       0           leaky_re_lu_466[0][0]
# __________________________________________________________________________________________________
# dropout_438 (Dropout)           (None, 32, 64)       0           leaky_re_lu_470[0][0]
# __________________________________________________________________________________________________
# raw_conv_4 (Conv1D)             (None, 16, 32)       6176        dropout_426[0][0]
# __________________________________________________________________________________________________
# fft_conv_4 (Conv1D)             (None, 9, 64)        12352       dropout_430[0][0]
# __________________________________________________________________________________________________
# fft_env_conv_4 (Conv1D)         (None, 9, 64)        12352       dropout_434[0][0]
# __________________________________________________________________________________________________
# wavelet_conv_4 (Conv1D)         (None, 16, 32)       6176        dropout_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_344 (BatchN (None, 16, 32)       128         raw_conv_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_347 (BatchN (None, 9, 64)        256         fft_conv_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_350 (BatchN (None, 9, 64)        256         fft_env_conv_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_353 (BatchN (None, 16, 32)       128         wavelet_conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_459 (LeakyReLU)     (None, 16, 32)       0           batch_normalization_344[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_463 (LeakyReLU)     (None, 9, 64)        0           batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_467 (LeakyReLU)     (None, 9, 64)        0           batch_normalization_350[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_471 (LeakyReLU)     (None, 16, 32)       0           batch_normalization_353[0][0]
# __________________________________________________________________________________________________
# dropout_427 (Dropout)           (None, 16, 32)       0           leaky_re_lu_459[0][0]
# __________________________________________________________________________________________________
# dropout_431 (Dropout)           (None, 9, 64)        0           leaky_re_lu_463[0][0]
# __________________________________________________________________________________________________
# dropout_435 (Dropout)           (None, 9, 64)        0           leaky_re_lu_467[0][0]
# __________________________________________________________________________________________________
# dropout_439 (Dropout)           (None, 16, 32)       0           leaky_re_lu_471[0][0]
# __________________________________________________________________________________________________
# flatten_146 (Flatten)           (None, 2048)         0           input_33[0][0]
# __________________________________________________________________________________________________
# flatten_147 (Flatten)           (None, 512)          0           dropout_427[0][0]
# __________________________________________________________________________________________________
# flatten_148 (Flatten)           (None, 576)          0           dropout_431[0][0]
# __________________________________________________________________________________________________
# flatten_149 (Flatten)           (None, 576)          0           dropout_435[0][0]
# __________________________________________________________________________________________________
# flatten_150 (Flatten)           (None, 512)          0           dropout_439[0][0]
# __________________________________________________________________________________________________
# minibatch_discrimination_18 (Mi (None, 2058)         61440       flatten_146[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 4234)         0           flatten_147[0][0]
#                                                                  flatten_148[0][0]
#                                                                  flatten_149[0][0]
#                                                                  flatten_150[0][0]
#                                                                  minibatch_discrimination_18[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 3)            12705       concatenate_27[0][0]
# ==================================================================================================
# Total params: 146,657
# Trainable params: 145,057
# Non-trainable params: 1,600
# __________________________________________________________________________________________________

# %%
train_model(cric.model,X,Y,binary=False)
# Out:
# Epoch 1/100
# 213/213 [==============================] - 13s 63ms/step - loss: 0.9136 - accuracy: 0.6152 - val_loss: 0.6949 - val_accuracy: 0.6948
# Epoch 2/100
# 213/213 [==============================] - 12s 57ms/step - loss: 0.6009 - accuracy: 0.7472 - val_loss: 0.6662 - val_accuracy: 0.7089
# Epoch 3/100
# 213/213 [==============================] - 11s 53ms/step - loss: 0.4586 - accuracy: 0.8136 - val_loss: 0.6570 - val_accuracy: 0.7160
# Epoch 4/100
# 213/213 [==============================] - 11s 53ms/step - loss: 0.3301 - accuracy: 0.8793 - val_loss: 0.6616 - val_accuracy: 0.7283
# Epoch 5/100
# 213/213 [==============================] - 12s 58ms/step - loss: 0.2244 - accuracy: 0.9307 - val_loss: 0.6729 - val_accuracy: 0.7236
# Epoch 6/100
# 213/213 [==============================] - 13s 61ms/step - loss: 0.1550 - accuracy: 0.9601 - val_loss: 0.6792 - val_accuracy: 0.7342
# Epoch 7/100
# 213/213 [==============================] - 14s 63ms/step - loss: 0.1043 - accuracy: 0.9781 - val_loss: 0.6780 - val_accuracy: 0.7289
# Epoch 8/100
# 213/213 [==============================] - 11s 53ms/step - loss: 0.0839 - accuracy: 0.9849 - val_loss: 0.7051 - val_accuracy: 0.7289
# Epoch 9/100
# 213/213 [==============================] - 11s 53ms/step - loss: 0.0651 - accuracy: 0.9883 - val_loss: 0.7050 - val_accuracy: 0.7371
# Epoch 10/100
# 213/213 [==============================] - 12s 54ms/step - loss: 0.0591 - accuracy: 0.9878 - val_loss: 0.7331 - val_accuracy: 0.7207
# Epoch 11/100
# 213/213 [==============================] - 12s 55ms/step - loss: 0.0572 - accuracy: 0.9861 - val_loss: 0.7474 - val_accuracy: 0.7195
# Epoch 12/100
# 213/213 [==============================] - 11s 54ms/step - loss: 0.0473 - accuracy: 0.9910 - val_loss: 0.7365 - val_accuracy: 0.7377
# Epoch 13/100
#  87/213 [===========>..................] - ETA: 7s - loss: 0.0352 - accuracy: 0.9943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-69401f86e9ae> in <module>
# ----> 1 train_model(cric.model,X,Y,binary=False)
#
# <ipython-input-5-443a3e33f0d1> in train_model(model, feature, y, binary, file)
#      46                         epochs=100,batch_size=32,class_weight=cw,
#      47                         callbacks=[early_stopping],
# ---> 48                         shuffle=True)
#      49
#      50     if binary:
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# E:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
test_model(cric.model,X2,Y2,False)
# Out:
# acc:0.721885
# [[242 150  84]
#  [125 910  42]
#  [ 84 111 395]]
# 0.7218852076528232

# %%
plt.plot(X[245,:,1])

# %%
model2 = Model(inputs=cric.model.input,outputs=cric.model.get_layer('wavelet_concat').output)

# %%
temp = model2.predict(X)

# %%
#for i in range(6):
#    plt.figure()
#    plt.plot(temp[100,i*100:(i+1)*100,0])
#    plt.grid(True)
plt.plot(temp[245,:,1])
#plt.plot(np.abs(tf.signal.rfft(X[:3,:,:],axis=1))[1,:,:])
#plt.plot(np.abs(X[16,:,6]))
#plt.grid(True)

# %%
temp.shape
# Out:
# (12862, 6144, 1)

# %%
n = 300
l = len(X[n,:,1])
end = (l-5)//1+1
env = []
for i in range(end):
    env += [np.mean(np.abs(X[n,i*1:i*1+5,1]))]

# %%
b, a = signal.butter(4, [wn], 'highpass')
plt.plot(env)
plt.plot(X[n,:,1])
plt.grid(True)
#plt.figure()
plt.plot(signal.filtfilt(b, a, X[n,:,1]))
plt.grid(True)

# %%
np.array([[1,2,3],[1,2,3]]).mean(axis=1)
# Out:
# array([2., 2.])
